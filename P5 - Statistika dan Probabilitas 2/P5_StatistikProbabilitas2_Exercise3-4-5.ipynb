# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
x_axis = np.arange(-10,10,0.001)

# %%
plt.plot(x_axis,norm.pdf(x_axis,0,2))
plt.grid()
plt.title('Kurva Distribusi Normal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu=10.0
sigma=2.0

# %%
data=np.random.randn(100000)*sigma+mu

# %%
hx, hy, _ = plt.hist(data,bins=50,color="r")
plt.ylim(0.0,max(hx)+0.05)
plt.title('Generate random numbers \n from a normal distribution with python')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data=np.random.randn(10000)

# %%
hx, hy, _ = plt.hist(data,bins=50,color="b")
plt.ylim(0.0,max(hx)+0.05)
plt.title('Generate random numbers \n from a normal distribution with python')
plt.grid()
plt.show()
